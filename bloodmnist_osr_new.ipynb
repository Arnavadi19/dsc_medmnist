# %%
# !python NirvanaOSR.py     --dataset bloodmnist     --model resnet18     --dataroot /home/arnav/reaching_nirvana/dsc/data     --lr 0.01 --max-epoch 200
# Out:
# Using device: cuda
# Currently using GPU: 1
# bloodmnist Preparation
# BloodMNIST_OSR Known classes: [0, 2, 5, 7]
# BloodMNIST_OSR Unknown classes: [1, 3, 4, 6]
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# BloodMNIST_OSR Training set class distribution: [ 852 2181 1085 2026  849  993 2330 1643]
# BloodMNIST_OSR Train samples: 4573
# BloodMNIST_OSR Test samples (known): 1309
# BloodMNIST_OSR Test samples (unknown): 2112
# Outlier exposure mode is on. Other datasets
# Loaded background dataset with 300000 images
# Background loader created with 2343 batches
# Creating model: resnet18
# Centers loaded.
# ==> Epoch 1/200
# ^C
# Traceback (most recent call last):
#   File "/home/arnav/dsc_new/NirvanaOSR.py", line 297, in <module>
#     res, res_b9 = main_worker(options)
#                   ^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import pandas as pd

results = pd.read_csv('/home/arnav/dsc_new/logs_results/results/resnet18_NirvanaOpenset_48.0_True_0.0/bloodmnist.csv')
results_b9 = pd.read_csv('/home/arnav/dsc_new/logs_results/results/resnet18_NirvanaOpenset_48.0_True_0.0/bloodmnist_b9.csv')
display(results), display(results_b9)
# Out:
#   Unnamed: 0                   0                   1                  2  \
# 0        TNR  15.246212121212121  22.747497219132374  21.14695340501792
# 1      AUROC   80.49466687501447   71.76800813116785  75.61973909074504
# 2      DTACC   77.60337089381207    73.5893136551395  69.62671648497843
# 3       AUIN   68.51819291123155   58.39072678988278   83.0581859261784
# 4      AUOUT   83.55119603345493   75.95914785728132  63.55266422233824
# 5        ACC   95.18716577540107   98.39802834257547  97.13721618953603
# 6       OSCR   78.63478294210253   70.70989056780422  74.70209852561848
# 7    unknown        [1, 3, 4, 6]        [1, 3, 2, 5]       [0, 1, 4, 5]
# 8      known        [0, 2, 5, 7]        [0, 6, 7, 4]       [2, 3, 6, 7]
#
#                    3                   4
# 0  26.44026682838083  25.958099131323454
# 1  69.55080512575513   81.00939321086419
# 2   63.5940346909749   74.28311846782323
# 3    72.532713043685    78.5131852451722
# ...

# %%
# !python NirvanaOSR.py     --dataset bloodmnist     --model resnet34     --dataroot /home/arnav/reaching_nirvana/dsc/data     --lr 0.01 --max-epoch 200
# Out:
# Using device: cuda
# Currently using GPU: 1
# bloodmnist Preparation
# BloodMNIST_OSR Known classes: [0, 2, 5, 7]
# BloodMNIST_OSR Unknown classes: [1, 3, 4, 6]
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# BloodMNIST_OSR Training set class distribution: [ 852 2181 1085 2026  849  993 2330 1643]
# BloodMNIST_OSR Train samples: 4573
# BloodMNIST_OSR Test samples (known): 1309
# BloodMNIST_OSR Test samples (unknown): 2112
# Outlier exposure mode is on. Other datasets
# Loaded background dataset with 300000 images
# Background loader created with 2343 batches
# Creating model: resnet34
# Centers loaded.
# ==> Epoch 1/200
# Epoch 1 loss: 50.835895
# ==> Test NirvanaOpenset
# Acc: 18.64018
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     0.237 27.741 50.783 30.634 47.131
#        TNR    AUROC  DTACC  AUIN   AUOUT
# ...

# %%
import pandas as pd

results = pd.read_csv('/home/arnav/dsc_new/logs_results/results/resnet34_NirvanaOpenset_48.0_True_0.0/bloodmnist.csv')
results_b9 = pd.read_csv('/home/arnav/dsc_new/logs_results/results/resnet34_NirvanaOpenset_48.0_True_0.0/bloodmnist_b9.csv')
display(results), display(results_b9)
# Out:
#   Unnamed: 0                  0                   1                  2  \
# 0        TNR  4.261363636363635  3.5595105672969973  9.175627240143369
# 1      AUROC  74.89589844202142  63.797352709966646  64.92713010434247
# 2      DTACC  77.83573656735422   71.17634984308575  64.28741769186949
# 3       AUIN  68.40975264628345   59.01723025626604  66.77959284635526
# 4      AUOUT  73.76910672465806   58.78128162252667  53.29492956004036
# 5        ACC   96.1038961038961   91.00431300061614  95.31095755182626
# 6       OSCR  73.23153951663318  59.285493500343236  63.70741295063838
# 7    unknown       [1, 3, 4, 6]        [1, 3, 2, 5]       [0, 1, 4, 5]
# 8      known       [0, 2, 5, 7]        [0, 6, 7, 4]       [2, 3, 6, 7]
#
#                    3                   4
# 0  29.47240751970891  16.198262646908535
# 1  69.48817738912837   64.81036268851344
# 2  63.42293776787902    63.9644955337572
# 3  71.34763945928302  53.617962373489846
# 4  70.71446444300067   70.86621334541063
# ...

# %% [markdown]
# Retrying with resnet18 since its giving better results

# %%
# !python NirvanaOSR.py     --dataset bloodmnist     --model resnet18     --dataroot /home/arnav/reaching_nirvana/dsc/data     --lr 0.01 --max-epoch 300
# Out:
# Using device: cuda
# Currently using GPU: 1
# bloodmnist Preparation
# BloodMNIST_OSR Known classes: [0, 2, 5, 7]
# BloodMNIST_OSR Unknown classes: [1, 3, 4, 6]
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# BloodMNIST_OSR Training set class distribution: [ 852 2181 1085 2026  849  993 2330 1643]
# BloodMNIST_OSR Train samples: 4573
# BloodMNIST_OSR Test samples (known): 1309
# BloodMNIST_OSR Test samples (unknown): 2112
# Outlier exposure mode is on. Other datasets
# Loaded background dataset with 300000 images
# Background loader created with 2343 batches
# Creating model: resnet18
# Centers loaded.
# ==> Epoch 1/300
# Epoch 1 loss: 28.737984
# ==> Test NirvanaOpenset
# Acc: 18.64018
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     0.758 23.544 50.674 28.381 46.014
#        TNR    AUROC  DTACC  AUIN   AUOUT
# ...

# %%
# !python NirvanaOSR.py     --dataset bloodmnist     --model resnet18     --dataroot /home/arnav/reaching_nirvana/dsc/data     --lr 0.01 --max-epoch 300
# Out:
# /home/arnav/miniconda3/envs/ml/lib/python3.12/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1729647378361/work/c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Using device: cpu
# Currently using CPU
# bloodmnist Preparation
# BloodMNIST_OSR Known classes: [0, 2, 5, 7]
# BloodMNIST_OSR Unknown classes: [1, 3, 4, 6]
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# BloodMNIST_OSR Training set class distribution: [ 852 2181 1085 2026  849  993 2330 1643]
# BloodMNIST_OSR Train samples: 4573
# BloodMNIST_OSR Test samples (known): 1309
# ...

# %%
# !python NirvanaOSR.py     --dataset bloodmnist     --model resnet18     --dataroot /home/arnav/reaching_nirvana/dsc/data     --lr 0.01 --max-epoch 300
# Out:
# /home/arnav/miniconda3/envs/ml/lib/python3.12/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1729647378361/work/c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Using device: cpu
# Currently using CPU
# bloodmnist Preparation
# BloodMNIST_OSR Known classes: [0, 2, 5, 7]
# BloodMNIST_OSR Unknown classes: [1, 3, 4, 6]
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# Using downloaded and verified file: /home/arnav/reaching_nirvana/dsc/data/bloodmnist/bloodmnist.npz
# BloodMNIST_OSR Training set class distribution: [ 852 2181 1085 2026  849  993 2330 1643]
# BloodMNIST_OSR Train samples: 4573
# BloodMNIST_OSR Test samples (known): 1309
# ...

# %%
import pandas as pd

results = pd.read_csv('/home/arnav/dsc_new/logs_results/results/resnet18_NirvanaOpenset_48.0_True_0.0/bloodmnist.csv')
results_b9 = pd.read_csv('/home/arnav/dsc_new/logs_results/results/resnet18_NirvanaOpenset_48.0_True_0.0/bloodmnist_b9.csv')
display(results), display(results_b9)
# Out:
#   Unnamed: 0                  0                   1                   2  \
# 0        TNR  41.09848484848485  36.206896551724135  23.870967741935488
# 1      AUROC   86.7613419334676   81.62663793617473   78.02326033959955
# 2      DTACC   78.6084320091673   76.06293225100525   69.77457921571542
# 3       AUIN  81.73474494887559   75.94214257225623   85.58705414690868
# 4      AUOUT  89.83483407161906    82.9646202300328   68.03549807390435
# 5        ACC  97.63177998472116   99.19901417128774    97.2852912142152
# 6       OSCR  85.42643296988243   81.38821666025878   77.13693313094612
# 7    unknown       [1, 3, 4, 6]        [1, 3, 2, 5]        [0, 1, 4, 5]
# 8      known       [0, 2, 5, 7]        [0, 6, 7, 4]        [2, 3, 6, 7]
#
#                     3                   4
# 0  25.728155339805824  24.782830863566684
# 1   73.29552921656564   74.33686974877908
# 2   67.73039086842003   68.82514708305061
# 3   70.63341178368219   65.88626050057303
# ...
